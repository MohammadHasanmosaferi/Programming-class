# %%
#mohammad hasan mosaferi
#4042013200

main_students = {
        "first_name": "Ali",
        "last_name": "Rezaei",
        "student_code": "S12345",
        "date_of_birth": 1998,
        "age": 25,
        "desired_movie": "Inception",
        "desired_song": "Queen",
        "major": "Computer Engineering",
        "academic_level": "Msater",
        "entry_year": 2018,
        "gpa": 17.5,
        "favorite_courses": ["Algorithms", "Data Structures"],
        "hobbies": ["Reading", "Football"],
        "career_goal": "Software Developer",
        "strengths": ["Teamwork", "Problem-solving"],
        "weaknesses": ["Public speaking"],
        "favorite_book": "The Alchemist",
        "skills": ["Python", "C++"],
        "languages": ["English", "French"],
        "volunteer_experience": ["Teaching assistant"],
        "feedback": {
            "courses": "Challenging but rewarding",
            "professors": "Supportive and knowledgeable"
        }
}    

student_1 = {
        "first_name": "Mohammad Hasan",
        "last_name": "Misaferi",
        "student_code": "4042013200",
        "date_of_birth": 2007,
        "desired_movie": "Kung fu panda",
        "major": "Electrical Engineering",
        "academic_level": "BSc(Bachelor of science )",
        "gpa": 18/86,
        "favorite_courses": ["Algorithms"],
        "hobbies": ["studying", "working","chess"],
        "feedback": {
            "courses": "difficult bot worthwhile",
            "professors": "Encouraging and informed "
        }
}


for i in student_1 :
    for j in main_students :
        if i == j  :
            main_students[j] = student_1[i]

print(main_students)
# Out:
# {'first_name': 'Mohammad Hasan', 'last_name': 'Misaferi', 'student_code': '4042013200', 'date_of_birth': 2007, 'age': 25, 'desired_movie': 'Kung fu panda', 'desired_song': 'Queen', 'major': 'Electrical Engineering', 'academic_level': 'BSc(Bachelor of science )', 'entry_year': 2018, 'gpa': 0.20930232558139536, 'favorite_courses': ['Algorithms', 'Data Structures'], 'hobbies': ['studying', 'working', 'chess'], 'career_goal': 'Software Developer', 'strengths': ['Teamwork', 'Problem-solving'], 'weaknesses': ['Public speaking'], 'favorite_book': 'The Alchemist', 'skills': ['Python', 'C++'], 'languages': ['English', 'French'], 'volunteer_experience': ['Teaching assistant'], 'feedback': {'courses': 'difficult bot worthwhile', 'professors': 'Encouraging and informed '}}
